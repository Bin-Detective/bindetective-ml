# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
import kagglehub
path = kagglehub.dataset_download("bahiskaraananda/robin-base")

print("Path to dataset files:", path)
print('Data source import complete.')
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/bahiskaraananda/robin-base?dataset_version_number=1...
# 100%|██████████| 244M/244M [00:04<00:00, 61.7MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/bahiskaraananda/robin-base/versions/1
# Data source import complete.

# %%
# %pip install tensorflow==2.15
# Out:
# Collecting tensorflow==2.15
#   Downloading tensorflow-2.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (18.1.1)
# Collecting ml-dtypes~=0.2.0 (from tensorflow==2.15)
#   Downloading ml_dtypes-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (4.25.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (4.12.2)
# Collecting wrapt<1.15,>=1.11.0 (from tensorflow==2.15)
#   Downloading wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (1.68.1)
# Collecting tensorboard<2.16,>=2.15 (from tensorflow==2.15)
#   Downloading tensorboard-2.15.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting tensorflow-estimator<2.16,>=2.15.0 (from tensorflow==2.15)
#   Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras<2.16,>=2.15.0 (from tensorflow==2.15)
#   Downloading keras-2.15.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.15) (0.45.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15) (1.2.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15) (3.1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow==2.15) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15) (3.2.2)
# Downloading tensorflow-2.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (475.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.2/475.2 MB 2.5 MB/s eta 0:00:00
# Downloading keras-2.15.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 23.4 MB/s eta 0:00:00
# Downloading ml_dtypes-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 15.0 MB/s eta 0:00:00
# Downloading tensorboard-2.15.2-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 23.4 MB/s eta 0:00:00
# Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl (441 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.0/442.0 kB 25.7 MB/s eta 0:00:00
# Downloading wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 3.5 MB/s eta 0:00:00
# Installing collected packages: wrapt, tensorflow-estimator, ml-dtypes, keras, tensorboard, tensorflow
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.17.0
#     Uninstalling wrapt-1.17.0:
#       Successfully uninstalled wrapt-1.17.0
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.4.1
#     Uninstalling ml-dtypes-0.4.1:
#       Successfully uninstalled ml-dtypes-0.4.1
#   Attempting uninstall: keras
#     Found existing installation: keras 3.5.0
#     Uninstalling keras-3.5.0:
#       Successfully uninstalled keras-3.5.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.17.1
#     Uninstalling tensorboard-2.17.1:
#       Successfully uninstalled tensorboard-2.17.1
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.17.1
#     Uninstalling tensorflow-2.17.1:
#       Successfully uninstalled tensorflow-2.17.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorstore 0.1.69 requires ml-dtypes>=0.3.1, but you have ml-dtypes 0.2.0 which is incompatible.
# tf-keras 2.17.0 requires tensorflow<2.18,>=2.17, but you have tensorflow 2.15.0 which is incompatible.
# Successfully installed keras-2.15.0 ml-dtypes-0.2.0 tensorboard-2.15.2 tensorflow-2.15.0 tensorflow-estimator-2.15.0 wrapt-1.14.1

# %% [markdown]
# # Importing libraries

# %%
import tensorflow as tf
import keras
import sklearn
print("TensorFlow:", tf.__version__)
print("Keras:", keras.__version__)
print("scikit-learn:", sklearn.__version__)
# Out:
# TensorFlow: 2.15.0
# Keras: 2.15.0
# scikit-learn: 1.5.2

# %%
import warnings
warnings.filterwarnings('ignore')

import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.layers import Input, Activation, Add, Dense, Conv2D, GlobalAveragePooling2D, MaxPooling2D
from keras.layers import BatchNormalization, Dropout
from tensorflow.keras.applications import EfficientNetV2S
from tensorflow.keras.applications.efficientnet_v2 import preprocess_input
from tensorflow.keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
from keras.models import Model
from keras.utils import plot_model
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
#  # Setting up dataset paths

# %%
dataset_path = '/root/.cache/kagglehub/datasets/bahiskaraananda/robin-base/versions/1'
dataset_class = os.listdir(dataset_path)

train_dir = '/root/.cache/kagglehub/datasets/bahiskaraananda/robin-base/versions/1/train'
val_dir = '/root/.cache/kagglehub/datasets/bahiskaraananda/robin-base/versions/1/val'
test_dir = '/root/.cache/kagglehub/datasets/bahiskaraananda/robin-base/versions/1/test'

# %%
for split_dir in [train_dir, val_dir, test_dir]:
    print(f"Contents of {split_dir}:")
    for class_dir in os.listdir(split_dir):
        class_path = os.path.join(split_dir, class_dir)
        if os.path.isdir(class_path):
            print(f" - Class: {class_dir}, Number of images: {len(os.listdir(class_path))}")
# Out:
# Contents of /root/.cache/kagglehub/datasets/bahiskaraananda/robin-base/versions/1/train:
#  - Class: kertas, Number of images: 2099
#  - Class: kaca, Number of images: 2099
#  - Class: daun, Number of images: 2099
#  - Class: makanan, Number of images: 2099
#  - Class: buah_sayuran, Number of images: 2099
#  - Class: tekstil, Number of images: 2099
#  - Class: medis, Number of images: 2099
#  - Class: elektronik, Number of images: 2099
#  - Class: plastik, Number of images: 2099
#  - Class: logam, Number of images: 2099
# Contents of /root/.cache/kagglehub/datasets/bahiskaraananda/robin-base/versions/1/val:
#  - Class: kertas, Number of images: 600
#  - Class: kaca, Number of images: 600
#  - Class: daun, Number of images: 600
#  - Class: makanan, Number of images: 600
#  - Class: buah_sayuran, Number of images: 600
#  - Class: tekstil, Number of images: 600
#  - Class: medis, Number of images: 600
#  - Class: elektronik, Number of images: 600
#  - Class: plastik, Number of images: 600
#  - Class: logam, Number of images: 600
# Contents of /root/.cache/kagglehub/datasets/bahiskaraananda/robin-base/versions/1/test:
#  - Class: kertas, Number of images: 301
#  - Class: kaca, Number of images: 301
#  - Class: daun, Number of images: 301
#  - Class: makanan, Number of images: 301
#  - Class: buah_sayuran, Number of images: 301
#  - Class: tekstil, Number of images: 301
#  - Class: medis, Number of images: 301
#  - Class: elektronik, Number of images: 301
#  - Class: plastik, Number of images: 301
#  - Class: logam, Number of images: 301

# %%
data = []

for class_name in dataset_class:
    for file in os.listdir(os.path.join(dataset_path, class_name)):
        data.append((os.path.join(dataset_path, class_name, file), class_name))

df = pd.DataFrame(data, columns=['filepath', 'label'])
df.head()
# Out:
#                                             filepath label
# 0  /root/.cache/kagglehub/datasets/bahiskaraanand...   val
# 1  /root/.cache/kagglehub/datasets/bahiskaraanand...   val
# 2  /root/.cache/kagglehub/datasets/bahiskaraanand...   val
# 3  /root/.cache/kagglehub/datasets/bahiskaraanand...   val
# 4  /root/.cache/kagglehub/datasets/bahiskaraanand...   val

# %% [markdown]
# # Image preprocessing and augmentation

# %%
train_datagen = ImageDataGenerator(
    rotation_range=60,                       # Randomly rotate by up to 60 degrees
    width_shift_range=0.15,                  # Randomly shift horizontally by up to 15% of the width
    height_shift_range=0.15,                 # Randomly shift vertically by up to 15% of the height
    zoom_range=0.20,                         # Randomly zoom in or out by up to 20%
    horizontal_flip=True,                    # Randomly flip horizontally
    vertical_flip=True,                      # Randomly flip vertically
    shear_range=0.05,                        # Apply slight shear transformations
    brightness_range=[0.9, 1.1],             # Vary brightness between 90% to 110%
    channel_shift_range=10,                  # Randomly shift channels
    fill_mode='nearest',                     # Fill in missing pixels with the nearest value
    preprocessing_function=preprocess_input
)

val_test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

# %%
train_generator = train_datagen.flow_from_directory(
    directory=train_dir,
    target_size=(224, 224),
    batch_size=64,
    class_mode='categorical',
    seed=42
)

val_generator = val_test_datagen.flow_from_directory(
    directory=val_dir,
    target_size=(224, 224),
    batch_size=64,
    class_mode='categorical',
    shuffle=False,
    seed=42
)

test_generator = val_test_datagen.flow_from_directory(
    directory=test_dir,
    target_size=(224, 224),
    batch_size=64,
    class_mode='categorical',
    shuffle=False,
    seed=42
)
# Out:
# Found 20990 images belonging to 10 classes.
# Found 6000 images belonging to 10 classes.
# Found 3010 images belonging to 10 classes.

# %%
print(f"Number of batches in train_generator: {len(train_generator)}")
print(f"Number of batches in val_generator: {len(val_generator)}")
train_generator.class_indices
# Out:
# Number of batches in train_generator: 328
# Number of batches in val_generator: 94
# {'buah_sayuran': 0,
#  'daun': 1,
#  'elektronik': 2,
#  'kaca': 3,
#  'kertas': 4,
#  'logam': 5,
#  'makanan': 6,
#  'medis': 7,
#  'plastik': 8,
#  'tekstil': 9}

# %% [markdown]
# #  Loading the EfficientNetV2S pre-trained model

# %%
base_model = EfficientNetV2S(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-s_notop.h5
# 82420632/82420632 [==============================] - 0s 0us/step

# %%
base_model.summary()
# Out:
# Model: "efficientnetv2-s"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  rescaling (Rescaling)       (None, 224, 224, 3)          0         ['input_1[0][0]']
#
#  stem_conv (Conv2D)          (None, 112, 112, 24)         648       ['rescaling[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 112, 112, 24)         96        ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 112, 112, 24)         0         ['stem_bn[0][0]']
#  n)
#
#  block1a_project_conv (Conv  (None, 112, 112, 24)         5184      ['stem_activation[0][0]']
#  2D)
#
#  block1a_project_bn (BatchN  (None, 112, 112, 24)         96        ['block1a_project_conv[0][0]']
#  ormalization)
#
#  block1a_project_activation  (None, 112, 112, 24)         0         ['block1a_project_bn[0][0]']
#   (Activation)
#
#  block1a_add (Add)           (None, 112, 112, 24)         0         ['block1a_project_activation[0
#                                                                     ][0]',
#                                                                      'stem_activation[0][0]']
#
#  block1b_project_conv (Conv  (None, 112, 112, 24)         5184      ['block1a_add[0][0]']
#  2D)
#
#  block1b_project_bn (BatchN  (None, 112, 112, 24)         96        ['block1b_project_conv[0][0]']
#  ormalization)
#
#  block1b_project_activation  (None, 112, 112, 24)         0         ['block1b_project_bn[0][0]']
#   (Activation)
#
#  block1b_drop (Dropout)      (None, 112, 112, 24)         0         ['block1b_project_activation[0
#                                                                     ][0]']
#
#  block1b_add (Add)           (None, 112, 112, 24)         0         ['block1b_drop[0][0]',
#                                                                      'block1a_add[0][0]']
#
#  block2a_expand_conv (Conv2  (None, 56, 56, 96)           20736     ['block1b_add[0][0]']
#  D)
#
#  block2a_expand_bn (BatchNo  (None, 56, 56, 96)           384       ['block2a_expand_conv[0][0]']
#  rmalization)
#
#  block2a_expand_activation   (None, 56, 56, 96)           0         ['block2a_expand_bn[0][0]']
#  (Activation)
#
#  block2a_project_conv (Conv  (None, 56, 56, 48)           4608      ['block2a_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2a_project_bn (BatchN  (None, 56, 56, 48)           192       ['block2a_project_conv[0][0]']
#  ormalization)
#
#  block2b_expand_conv (Conv2  (None, 56, 56, 192)          82944     ['block2a_project_bn[0][0]']
#  D)
#
#  block2b_expand_bn (BatchNo  (None, 56, 56, 192)          768       ['block2b_expand_conv[0][0]']
#  rmalization)
#
#  block2b_expand_activation   (None, 56, 56, 192)          0         ['block2b_expand_bn[0][0]']
#  (Activation)
#
#  block2b_project_conv (Conv  (None, 56, 56, 48)           9216      ['block2b_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2b_project_bn (BatchN  (None, 56, 56, 48)           192       ['block2b_project_conv[0][0]']
#  ormalization)
#
#  block2b_drop (Dropout)      (None, 56, 56, 48)           0         ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)           (None, 56, 56, 48)           0         ['block2b_drop[0][0]',
#                                                                      'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2  (None, 56, 56, 192)          82944     ['block2b_add[0][0]']
#  D)
#
#  block2c_expand_bn (BatchNo  (None, 56, 56, 192)          768       ['block2c_expand_conv[0][0]']
#  rmalization)
#
#  block2c_expand_activation   (None, 56, 56, 192)          0         ['block2c_expand_bn[0][0]']
#  (Activation)
#
#  block2c_project_conv (Conv  (None, 56, 56, 48)           9216      ['block2c_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2c_project_bn (BatchN  (None, 56, 56, 48)           192       ['block2c_project_conv[0][0]']
#  ormalization)
#
#  block2c_drop (Dropout)      (None, 56, 56, 48)           0         ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)           (None, 56, 56, 48)           0         ['block2c_drop[0][0]',
#                                                                      'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2  (None, 56, 56, 192)          82944     ['block2c_add[0][0]']
#  D)
#
#  block2d_expand_bn (BatchNo  (None, 56, 56, 192)          768       ['block2d_expand_conv[0][0]']
#  rmalization)
#
#  block2d_expand_activation   (None, 56, 56, 192)          0         ['block2d_expand_bn[0][0]']
#  (Activation)
#
#  block2d_project_conv (Conv  (None, 56, 56, 48)           9216      ['block2d_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2d_project_bn (BatchN  (None, 56, 56, 48)           192       ['block2d_project_conv[0][0]']
#  ormalization)
#
#  block2d_drop (Dropout)      (None, 56, 56, 48)           0         ['block2d_project_bn[0][0]']
#
#  block2d_add (Add)           (None, 56, 56, 48)           0         ['block2d_drop[0][0]',
#                                                                      'block2c_add[0][0]']
#
#  block3a_expand_conv (Conv2  (None, 28, 28, 192)          82944     ['block2d_add[0][0]']
#  D)
#
#  block3a_expand_bn (BatchNo  (None, 28, 28, 192)          768       ['block3a_expand_conv[0][0]']
#  rmalization)
#
#  block3a_expand_activation   (None, 28, 28, 192)          0         ['block3a_expand_bn[0][0]']
#  (Activation)
#
#  block3a_project_conv (Conv  (None, 28, 28, 64)           12288     ['block3a_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3a_project_bn (BatchN  (None, 28, 28, 64)           256       ['block3a_project_conv[0][0]']
#  ormalization)
#
#  block3b_expand_conv (Conv2  (None, 28, 28, 256)          147456    ['block3a_project_bn[0][0]']
#  D)
#
#  block3b_expand_bn (BatchNo  (None, 28, 28, 256)          1024      ['block3b_expand_conv[0][0]']
#  rmalization)
#
#  block3b_expand_activation   (None, 28, 28, 256)          0         ['block3b_expand_bn[0][0]']
#  (Activation)
#
#  block3b_project_conv (Conv  (None, 28, 28, 64)           16384     ['block3b_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3b_project_bn (BatchN  (None, 28, 28, 64)           256       ['block3b_project_conv[0][0]']
#  ormalization)
#
#  block3b_drop (Dropout)      (None, 28, 28, 64)           0         ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)           (None, 28, 28, 64)           0         ['block3b_drop[0][0]',
#                                                                      'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2  (None, 28, 28, 256)          147456    ['block3b_add[0][0]']
#  D)
#
#  block3c_expand_bn (BatchNo  (None, 28, 28, 256)          1024      ['block3c_expand_conv[0][0]']
#  rmalization)
#
#  block3c_expand_activation   (None, 28, 28, 256)          0         ['block3c_expand_bn[0][0]']
#  (Activation)
#
#  block3c_project_conv (Conv  (None, 28, 28, 64)           16384     ['block3c_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3c_project_bn (BatchN  (None, 28, 28, 64)           256       ['block3c_project_conv[0][0]']
#  ormalization)
#
#  block3c_drop (Dropout)      (None, 28, 28, 64)           0         ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)           (None, 28, 28, 64)           0         ['block3c_drop[0][0]',
#                                                                      'block3b_add[0][0]']
#
#  block3d_expand_conv (Conv2  (None, 28, 28, 256)          147456    ['block3c_add[0][0]']
#  D)
#
#  block3d_expand_bn (BatchNo  (None, 28, 28, 256)          1024      ['block3d_expand_conv[0][0]']
#  rmalization)
#
#  block3d_expand_activation   (None, 28, 28, 256)          0         ['block3d_expand_bn[0][0]']
#  (Activation)
#
#  block3d_project_conv (Conv  (None, 28, 28, 64)           16384     ['block3d_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3d_project_bn (BatchN  (None, 28, 28, 64)           256       ['block3d_project_conv[0][0]']
#  ormalization)
#
#  block3d_drop (Dropout)      (None, 28, 28, 64)           0         ['block3d_project_bn[0][0]']
#
#  block3d_add (Add)           (None, 28, 28, 64)           0         ['block3d_drop[0][0]',
#                                                                      'block3c_add[0][0]']
#
#  block4a_expand_conv (Conv2  (None, 28, 28, 256)          16384     ['block3d_add[0][0]']
#  D)
#
#  block4a_expand_bn (BatchNo  (None, 28, 28, 256)          1024      ['block4a_expand_conv[0][0]']
#  rmalization)
#
#  block4a_expand_activation   (None, 28, 28, 256)          0         ['block4a_expand_bn[0][0]']
#  (Activation)
#
#  block4a_dwconv2 (Depthwise  (None, 14, 14, 256)          2304      ['block4a_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4a_bn (BatchNormaliza  (None, 14, 14, 256)          1024      ['block4a_dwconv2[0][0]']
#  tion)
#
#  block4a_activation (Activa  (None, 14, 14, 256)          0         ['block4a_bn[0][0]']
#  tion)
#
#  block4a_se_squeeze (Global  (None, 256)                  0         ['block4a_activation[0][0]']
#  AveragePooling2D)
#
#  block4a_se_reshape (Reshap  (None, 1, 1, 256)            0         ['block4a_se_squeeze[0][0]']
#  e)
#
#  block4a_se_reduce (Conv2D)  (None, 1, 1, 16)             4112      ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)  (None, 1, 1, 256)            4352      ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multipl  (None, 14, 14, 256)          0         ['block4a_activation[0][0]',
#  y)                                                                  'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv  (None, 14, 14, 128)          32768     ['block4a_se_excite[0][0]']
#  2D)
#
#  block4a_project_bn (BatchN  (None, 14, 14, 128)          512       ['block4a_project_conv[0][0]']
#  ormalization)
#
#  block4b_expand_conv (Conv2  (None, 14, 14, 512)          65536     ['block4a_project_bn[0][0]']
#  D)
#
#  block4b_expand_bn (BatchNo  (None, 14, 14, 512)          2048      ['block4b_expand_conv[0][0]']
#  rmalization)
#
#  block4b_expand_activation   (None, 14, 14, 512)          0         ['block4b_expand_bn[0][0]']
#  (Activation)
#
#  block4b_dwconv2 (Depthwise  (None, 14, 14, 512)          4608      ['block4b_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4b_bn (BatchNormaliza  (None, 14, 14, 512)          2048      ['block4b_dwconv2[0][0]']
#  tion)
#
#  block4b_activation (Activa  (None, 14, 14, 512)          0         ['block4b_bn[0][0]']
#  tion)
#
#  block4b_se_squeeze (Global  (None, 512)                  0         ['block4b_activation[0][0]']
#  AveragePooling2D)
#
#  block4b_se_reshape (Reshap  (None, 1, 1, 512)            0         ['block4b_se_squeeze[0][0]']
#  e)
#
#  block4b_se_reduce (Conv2D)  (None, 1, 1, 32)             16416     ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)  (None, 1, 1, 512)            16896     ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multipl  (None, 14, 14, 512)          0         ['block4b_activation[0][0]',
#  y)                                                                  'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv  (None, 14, 14, 128)          65536     ['block4b_se_excite[0][0]']
#  2D)
#
#  block4b_project_bn (BatchN  (None, 14, 14, 128)          512       ['block4b_project_conv[0][0]']
#  ormalization)
#
#  block4b_drop (Dropout)      (None, 14, 14, 128)          0         ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)           (None, 14, 14, 128)          0         ['block4b_drop[0][0]',
#                                                                      'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2  (None, 14, 14, 512)          65536     ['block4b_add[0][0]']
#  D)
#
#  block4c_expand_bn (BatchNo  (None, 14, 14, 512)          2048      ['block4c_expand_conv[0][0]']
#  rmalization)
#
#  block4c_expand_activation   (None, 14, 14, 512)          0         ['block4c_expand_bn[0][0]']
#  (Activation)
#
#  block4c_dwconv2 (Depthwise  (None, 14, 14, 512)          4608      ['block4c_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4c_bn (BatchNormaliza  (None, 14, 14, 512)          2048      ['block4c_dwconv2[0][0]']
#  tion)
#
#  block4c_activation (Activa  (None, 14, 14, 512)          0         ['block4c_bn[0][0]']
#  tion)
#
#  block4c_se_squeeze (Global  (None, 512)                  0         ['block4c_activation[0][0]']
#  AveragePooling2D)
#
#  block4c_se_reshape (Reshap  (None, 1, 1, 512)            0         ['block4c_se_squeeze[0][0]']
#  e)
#
#  block4c_se_reduce (Conv2D)  (None, 1, 1, 32)             16416     ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)  (None, 1, 1, 512)            16896     ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multipl  (None, 14, 14, 512)          0         ['block4c_activation[0][0]',
#  y)                                                                  'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv  (None, 14, 14, 128)          65536     ['block4c_se_excite[0][0]']
#  2D)
#
#  block4c_project_bn (BatchN  (None, 14, 14, 128)          512       ['block4c_project_conv[0][0]']
#  ormalization)
#
#  block4c_drop (Dropout)      (None, 14, 14, 128)          0         ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)           (None, 14, 14, 128)          0         ['block4c_drop[0][0]',
#                                                                      'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2  (None, 14, 14, 512)          65536     ['block4c_add[0][0]']
#  D)
#
#  block4d_expand_bn (BatchNo  (None, 14, 14, 512)          2048      ['block4d_expand_conv[0][0]']
#  rmalization)
#
#  block4d_expand_activation   (None, 14, 14, 512)          0         ['block4d_expand_bn[0][0]']
#  (Activation)
#
#  block4d_dwconv2 (Depthwise  (None, 14, 14, 512)          4608      ['block4d_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4d_bn (BatchNormaliza  (None, 14, 14, 512)          2048      ['block4d_dwconv2[0][0]']
#  tion)
#
#  block4d_activation (Activa  (None, 14, 14, 512)          0         ['block4d_bn[0][0]']
#  tion)
#
#  block4d_se_squeeze (Global  (None, 512)                  0         ['block4d_activation[0][0]']
#  AveragePooling2D)
#
#  block4d_se_reshape (Reshap  (None, 1, 1, 512)            0         ['block4d_se_squeeze[0][0]']
#  e)
#
#  block4d_se_reduce (Conv2D)  (None, 1, 1, 32)             16416     ['block4d_se_reshape[0][0]']
#
#  block4d_se_expand (Conv2D)  (None, 1, 1, 512)            16896     ['block4d_se_reduce[0][0]']
#
#  block4d_se_excite (Multipl  (None, 14, 14, 512)          0         ['block4d_activation[0][0]',
#  y)                                                                  'block4d_se_expand[0][0]']
#
#  block4d_project_conv (Conv  (None, 14, 14, 128)          65536     ['block4d_se_excite[0][0]']
#  2D)
#
#  block4d_project_bn (BatchN  (None, 14, 14, 128)          512       ['block4d_project_conv[0][0]']
#  ormalization)
#
#  block4d_drop (Dropout)      (None, 14, 14, 128)          0         ['block4d_project_bn[0][0]']
#
#  block4d_add (Add)           (None, 14, 14, 128)          0         ['block4d_drop[0][0]',
#                                                                      'block4c_add[0][0]']
#
#  block4e_expand_conv (Conv2  (None, 14, 14, 512)          65536     ['block4d_add[0][0]']
#  D)
#
#  block4e_expand_bn (BatchNo  (None, 14, 14, 512)          2048      ['block4e_expand_conv[0][0]']
#  rmalization)
#
#  block4e_expand_activation   (None, 14, 14, 512)          0         ['block4e_expand_bn[0][0]']
#  (Activation)
#
#  block4e_dwconv2 (Depthwise  (None, 14, 14, 512)          4608      ['block4e_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4e_bn (BatchNormaliza  (None, 14, 14, 512)          2048      ['block4e_dwconv2[0][0]']
#  tion)
#
#  block4e_activation (Activa  (None, 14, 14, 512)          0         ['block4e_bn[0][0]']
#  tion)
#
#  block4e_se_squeeze (Global  (None, 512)                  0         ['block4e_activation[0][0]']
#  AveragePooling2D)
#
#  block4e_se_reshape (Reshap  (None, 1, 1, 512)            0         ['block4e_se_squeeze[0][0]']
#  e)
#
#  block4e_se_reduce (Conv2D)  (None, 1, 1, 32)             16416     ['block4e_se_reshape[0][0]']
#
#  block4e_se_expand (Conv2D)  (None, 1, 1, 512)            16896     ['block4e_se_reduce[0][0]']
#
#  block4e_se_excite (Multipl  (None, 14, 14, 512)          0         ['block4e_activation[0][0]',
#  y)                                                                  'block4e_se_expand[0][0]']
#
#  block4e_project_conv (Conv  (None, 14, 14, 128)          65536     ['block4e_se_excite[0][0]']
#  2D)
#
#  block4e_project_bn (BatchN  (None, 14, 14, 128)          512       ['block4e_project_conv[0][0]']
#  ormalization)
#
#  block4e_drop (Dropout)      (None, 14, 14, 128)          0         ['block4e_project_bn[0][0]']
#
#  block4e_add (Add)           (None, 14, 14, 128)          0         ['block4e_drop[0][0]',
#                                                                      'block4d_add[0][0]']
#
#  block4f_expand_conv (Conv2  (None, 14, 14, 512)          65536     ['block4e_add[0][0]']
#  D)
#
#  block4f_expand_bn (BatchNo  (None, 14, 14, 512)          2048      ['block4f_expand_conv[0][0]']
#  rmalization)
#
#  block4f_expand_activation   (None, 14, 14, 512)          0         ['block4f_expand_bn[0][0]']
#  (Activation)
#
#  block4f_dwconv2 (Depthwise  (None, 14, 14, 512)          4608      ['block4f_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4f_bn (BatchNormaliza  (None, 14, 14, 512)          2048      ['block4f_dwconv2[0][0]']
#  tion)
#
#  block4f_activation (Activa  (None, 14, 14, 512)          0         ['block4f_bn[0][0]']
#  tion)
#
#  block4f_se_squeeze (Global  (None, 512)                  0         ['block4f_activation[0][0]']
#  AveragePooling2D)
#
#  block4f_se_reshape (Reshap  (None, 1, 1, 512)            0         ['block4f_se_squeeze[0][0]']
#  e)
#
#  block4f_se_reduce (Conv2D)  (None, 1, 1, 32)             16416     ['block4f_se_reshape[0][0]']
#
#  block4f_se_expand (Conv2D)  (None, 1, 1, 512)            16896     ['block4f_se_reduce[0][0]']
#
#  block4f_se_excite (Multipl  (None, 14, 14, 512)          0         ['block4f_activation[0][0]',
#  y)                                                                  'block4f_se_expand[0][0]']
#
#  block4f_project_conv (Conv  (None, 14, 14, 128)          65536     ['block4f_se_excite[0][0]']
#  2D)
#
#  block4f_project_bn (BatchN  (None, 14, 14, 128)          512       ['block4f_project_conv[0][0]']
#  ormalization)
#
#  block4f_drop (Dropout)      (None, 14, 14, 128)          0         ['block4f_project_bn[0][0]']
#
#  block4f_add (Add)           (None, 14, 14, 128)          0         ['block4f_drop[0][0]',
#                                                                      'block4e_add[0][0]']
#
#  block5a_expand_conv (Conv2  (None, 14, 14, 768)          98304     ['block4f_add[0][0]']
#  D)
#
#  block5a_expand_bn (BatchNo  (None, 14, 14, 768)          3072      ['block5a_expand_conv[0][0]']
#  rmalization)
#
#  block5a_expand_activation   (None, 14, 14, 768)          0         ['block5a_expand_bn[0][0]']
#  (Activation)
#
#  block5a_dwconv2 (Depthwise  (None, 14, 14, 768)          6912      ['block5a_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block5a_bn (BatchNormaliza  (None, 14, 14, 768)          3072      ['block5a_dwconv2[0][0]']
#  tion)
#
#  block5a_activation (Activa  (None, 14, 14, 768)          0         ['block5a_bn[0][0]']
#  tion)
#
#  block5a_se_squeeze (Global  (None, 768)                  0         ['block5a_activation[0][0]']
#  AveragePooling2D)
#
#  block5a_se_reshape (Reshap  (None, 1, 1, 768)            0         ['block5a_se_squeeze[0][0]']
#  e)
#
#  block5a_se_reduce (Conv2D)  (None, 1, 1, 32)             24608     ['block5a_se_reshape[0][0]']
#
#  block5a_se_expand (Conv2D)  (None, 1, 1, 768)            25344     ['block5a_se_reduce[0][0]']
#
#  block5a_se_excite (Multipl  (None, 14, 14, 768)          0         ['block5a_activation[0][0]',
#  y)                                                                  'block5a_se_expand[0][0]']
#
#  block5a_project_conv (Conv  (None, 14, 14, 160)          122880    ['block5a_se_excite[0][0]']
#  2D)
#
#  block5a_project_bn (BatchN  (None, 14, 14, 160)          640       ['block5a_project_conv[0][0]']
#  ormalization)
#
#  block5b_expand_conv (Conv2  (None, 14, 14, 960)          153600    ['block5a_project_bn[0][0]']
#  D)
#
#  block5b_expand_bn (BatchNo  (None, 14, 14, 960)          3840      ['block5b_expand_conv[0][0]']
#  rmalization)
#
#  block5b_expand_activation   (None, 14, 14, 960)          0         ['block5b_expand_bn[0][0]']
# ...
#  block6l_se_squeeze (Global  (None, 1536)                 0         ['block6l_activation[0][0]']
#  AveragePooling2D)
#
#  block6l_se_reshape (Reshap  (None, 1, 1, 1536)           0         ['block6l_se_squeeze[0][0]']
#  e)
#
#  block6l_se_reduce (Conv2D)  (None, 1, 1, 64)             98368     ['block6l_se_reshape[0][0]']
#
#  block6l_se_expand (Conv2D)  (None, 1, 1, 1536)           99840     ['block6l_se_reduce[0][0]']
#
#  block6l_se_excite (Multipl  (None, 7, 7, 1536)           0         ['block6l_activation[0][0]',
#  y)                                                                  'block6l_se_expand[0][0]']
#
#  block6l_project_conv (Conv  (None, 7, 7, 256)            393216    ['block6l_se_excite[0][0]']
#  2D)
#
#  block6l_project_bn (BatchN  (None, 7, 7, 256)            1024      ['block6l_project_conv[0][0]']
#  ormalization)
#
#  block6l_drop (Dropout)      (None, 7, 7, 256)            0         ['block6l_project_bn[0][0]']
#
#  block6l_add (Add)           (None, 7, 7, 256)            0         ['block6l_drop[0][0]',
#                                                                      'block6k_add[0][0]']
#
#  block6m_expand_conv (Conv2  (None, 7, 7, 1536)           393216    ['block6l_add[0][0]']
#  D)
#
#  block6m_expand_bn (BatchNo  (None, 7, 7, 1536)           6144      ['block6m_expand_conv[0][0]']
#  rmalization)
#
#  block6m_expand_activation   (None, 7, 7, 1536)           0         ['block6m_expand_bn[0][0]']
#  (Activation)
#
#  block6m_dwconv2 (Depthwise  (None, 7, 7, 1536)           13824     ['block6m_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block6m_bn (BatchNormaliza  (None, 7, 7, 1536)           6144      ['block6m_dwconv2[0][0]']
#  tion)
#
#  block6m_activation (Activa  (None, 7, 7, 1536)           0         ['block6m_bn[0][0]']
#  tion)
#
#  block6m_se_squeeze (Global  (None, 1536)                 0         ['block6m_activation[0][0]']
#  AveragePooling2D)
#
#  block6m_se_reshape (Reshap  (None, 1, 1, 1536)           0         ['block6m_se_squeeze[0][0]']
#  e)
#
#  block6m_se_reduce (Conv2D)  (None, 1, 1, 64)             98368     ['block6m_se_reshape[0][0]']
#
#  block6m_se_expand (Conv2D)  (None, 1, 1, 1536)           99840     ['block6m_se_reduce[0][0]']
#
#  block6m_se_excite (Multipl  (None, 7, 7, 1536)           0         ['block6m_activation[0][0]',
#  y)                                                                  'block6m_se_expand[0][0]']
#
#  block6m_project_conv (Conv  (None, 7, 7, 256)            393216    ['block6m_se_excite[0][0]']
#  2D)
#
#  block6m_project_bn (BatchN  (None, 7, 7, 256)            1024      ['block6m_project_conv[0][0]']
#  ormalization)
#
#  block6m_drop (Dropout)      (None, 7, 7, 256)            0         ['block6m_project_bn[0][0]']
#
#  block6m_add (Add)           (None, 7, 7, 256)            0         ['block6m_drop[0][0]',
#                                                                      'block6l_add[0][0]']
#
#  block6n_expand_conv (Conv2  (None, 7, 7, 1536)           393216    ['block6m_add[0][0]']
#  D)
#
#  block6n_expand_bn (BatchNo  (None, 7, 7, 1536)           6144      ['block6n_expand_conv[0][0]']
#  rmalization)
#
#  block6n_expand_activation   (None, 7, 7, 1536)           0         ['block6n_expand_bn[0][0]']
#  (Activation)
#
#  block6n_dwconv2 (Depthwise  (None, 7, 7, 1536)           13824     ['block6n_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block6n_bn (BatchNormaliza  (None, 7, 7, 1536)           6144      ['block6n_dwconv2[0][0]']
#  tion)
#
#  block6n_activation (Activa  (None, 7, 7, 1536)           0         ['block6n_bn[0][0]']
#  tion)
#
#  block6n_se_squeeze (Global  (None, 1536)                 0         ['block6n_activation[0][0]']
#  AveragePooling2D)
#
#  block6n_se_reshape (Reshap  (None, 1, 1, 1536)           0         ['block6n_se_squeeze[0][0]']
#  e)
#
#  block6n_se_reduce (Conv2D)  (None, 1, 1, 64)             98368     ['block6n_se_reshape[0][0]']
#
#  block6n_se_expand (Conv2D)  (None, 1, 1, 1536)           99840     ['block6n_se_reduce[0][0]']
#
#  block6n_se_excite (Multipl  (None, 7, 7, 1536)           0         ['block6n_activation[0][0]',
#  y)                                                                  'block6n_se_expand[0][0]']
#
#  block6n_project_conv (Conv  (None, 7, 7, 256)            393216    ['block6n_se_excite[0][0]']
#  2D)
#
#  block6n_project_bn (BatchN  (None, 7, 7, 256)            1024      ['block6n_project_conv[0][0]']
#  ormalization)
#
#  block6n_drop (Dropout)      (None, 7, 7, 256)            0         ['block6n_project_bn[0][0]']
#
#  block6n_add (Add)           (None, 7, 7, 256)            0         ['block6n_drop[0][0]',
#                                                                      'block6m_add[0][0]']
#
#  block6o_expand_conv (Conv2  (None, 7, 7, 1536)           393216    ['block6n_add[0][0]']
#  D)
#
#  block6o_expand_bn (BatchNo  (None, 7, 7, 1536)           6144      ['block6o_expand_conv[0][0]']
#  rmalization)
#
#  block6o_expand_activation   (None, 7, 7, 1536)           0         ['block6o_expand_bn[0][0]']
#  (Activation)
#
#  block6o_dwconv2 (Depthwise  (None, 7, 7, 1536)           13824     ['block6o_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block6o_bn (BatchNormaliza  (None, 7, 7, 1536)           6144      ['block6o_dwconv2[0][0]']
#  tion)
#
#  block6o_activation (Activa  (None, 7, 7, 1536)           0         ['block6o_bn[0][0]']
#  tion)
#
#  block6o_se_squeeze (Global  (None, 1536)                 0         ['block6o_activation[0][0]']
#  AveragePooling2D)
#
#  block6o_se_reshape (Reshap  (None, 1, 1, 1536)           0         ['block6o_se_squeeze[0][0]']
#  e)
#
#  block6o_se_reduce (Conv2D)  (None, 1, 1, 64)             98368     ['block6o_se_reshape[0][0]']
#
#  block6o_se_expand (Conv2D)  (None, 1, 1, 1536)           99840     ['block6o_se_reduce[0][0]']
#
#  block6o_se_excite (Multipl  (None, 7, 7, 1536)           0         ['block6o_activation[0][0]',
#  y)                                                                  'block6o_se_expand[0][0]']
#
#  block6o_project_conv (Conv  (None, 7, 7, 256)            393216    ['block6o_se_excite[0][0]']
#  2D)
#
#  block6o_project_bn (BatchN  (None, 7, 7, 256)            1024      ['block6o_project_conv[0][0]']
#  ormalization)
#
#  block6o_drop (Dropout)      (None, 7, 7, 256)            0         ['block6o_project_bn[0][0]']
#
#  block6o_add (Add)           (None, 7, 7, 256)            0         ['block6o_drop[0][0]',
#                                                                      'block6n_add[0][0]']
#
#  top_conv (Conv2D)           (None, 7, 7, 1280)           327680    ['block6o_add[0][0]']
#
#  top_bn (BatchNormalization  (None, 7, 7, 1280)           5120      ['top_conv[0][0]']
#  )
#
#  top_activation (Activation  (None, 7, 7, 1280)           0         ['top_bn[0][0]']
#  )
#
# ==================================================================================================
# Total params: 20331360 (77.56 MB)
# Trainable params: 20177488 (76.97 MB)
# Non-trainable params: 153872 (601.06 KB)
# __________________________________________________________________________________________________

# %%
print(f'Total number of layers: {len(base_model.layers)}')
# Out:
# Total number of layers: 513

# %% [markdown]
# #  Freezing layers and adding custom layers

# %%
for i, layer in enumerate(base_model.layers):
    if 150 <= i <= 170:
        print(i, layer.name)
# Out:
# 150 block4f_project_conv
# 151 block4f_project_bn
# 152 block4f_drop
# 153 block4f_add
# 154 block5a_expand_conv
# 155 block5a_expand_bn
# 156 block5a_expand_activation
# 157 block5a_dwconv2
# 158 block5a_bn
# 159 block5a_activation
# 160 block5a_se_squeeze
# 161 block5a_se_reshape
# 162 block5a_se_reduce
# 163 block5a_se_expand
# 164 block5a_se_excite
# 165 block5a_project_conv
# 166 block5a_project_bn
# 167 block5b_expand_conv
# 168 block5b_expand_bn
# 169 block5b_expand_activation
# 170 block5b_dwconv2

# %%
for layer in base_model.layers[:153]:
    layer.trainable = False

# %%
x = GlobalAveragePooling2D()(base_model.output)
x = Dropout(0.5)(x)
output = Dense(10, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)
model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  rescaling (Rescaling)       (None, 224, 224, 3)          0         ['input_1[0][0]']
#
#  stem_conv (Conv2D)          (None, 112, 112, 24)         648       ['rescaling[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 112, 112, 24)         96        ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 112, 112, 24)         0         ['stem_bn[0][0]']
#  n)
#
#  block1a_project_conv (Conv  (None, 112, 112, 24)         5184      ['stem_activation[0][0]']
#  2D)
#
#  block1a_project_bn (BatchN  (None, 112, 112, 24)         96        ['block1a_project_conv[0][0]']
#  ormalization)
#
#  block1a_project_activation  (None, 112, 112, 24)         0         ['block1a_project_bn[0][0]']
#   (Activation)
#
#  block1a_add (Add)           (None, 112, 112, 24)         0         ['block1a_project_activation[0
#                                                                     ][0]',
#                                                                      'stem_activation[0][0]']
#
#  block1b_project_conv (Conv  (None, 112, 112, 24)         5184      ['block1a_add[0][0]']
#  2D)
#
#  block1b_project_bn (BatchN  (None, 112, 112, 24)         96        ['block1b_project_conv[0][0]']
#  ormalization)
#
#  block1b_project_activation  (None, 112, 112, 24)         0         ['block1b_project_bn[0][0]']
#   (Activation)
#
#  block1b_drop (Dropout)      (None, 112, 112, 24)         0         ['block1b_project_activation[0
#                                                                     ][0]']
#
#  block1b_add (Add)           (None, 112, 112, 24)         0         ['block1b_drop[0][0]',
#                                                                      'block1a_add[0][0]']
#
#  block2a_expand_conv (Conv2  (None, 56, 56, 96)           20736     ['block1b_add[0][0]']
#  D)
#
#  block2a_expand_bn (BatchNo  (None, 56, 56, 96)           384       ['block2a_expand_conv[0][0]']
#  rmalization)
#
#  block2a_expand_activation   (None, 56, 56, 96)           0         ['block2a_expand_bn[0][0]']
#  (Activation)
#
#  block2a_project_conv (Conv  (None, 56, 56, 48)           4608      ['block2a_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2a_project_bn (BatchN  (None, 56, 56, 48)           192       ['block2a_project_conv[0][0]']
#  ormalization)
#
#  block2b_expand_conv (Conv2  (None, 56, 56, 192)          82944     ['block2a_project_bn[0][0]']
#  D)
#
#  block2b_expand_bn (BatchNo  (None, 56, 56, 192)          768       ['block2b_expand_conv[0][0]']
#  rmalization)
#
#  block2b_expand_activation   (None, 56, 56, 192)          0         ['block2b_expand_bn[0][0]']
#  (Activation)
#
#  block2b_project_conv (Conv  (None, 56, 56, 48)           9216      ['block2b_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2b_project_bn (BatchN  (None, 56, 56, 48)           192       ['block2b_project_conv[0][0]']
#  ormalization)
#
#  block2b_drop (Dropout)      (None, 56, 56, 48)           0         ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)           (None, 56, 56, 48)           0         ['block2b_drop[0][0]',
#                                                                      'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2  (None, 56, 56, 192)          82944     ['block2b_add[0][0]']
#  D)
#
#  block2c_expand_bn (BatchNo  (None, 56, 56, 192)          768       ['block2c_expand_conv[0][0]']
#  rmalization)
#
#  block2c_expand_activation   (None, 56, 56, 192)          0         ['block2c_expand_bn[0][0]']
#  (Activation)
#
#  block2c_project_conv (Conv  (None, 56, 56, 48)           9216      ['block2c_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2c_project_bn (BatchN  (None, 56, 56, 48)           192       ['block2c_project_conv[0][0]']
#  ormalization)
#
#  block2c_drop (Dropout)      (None, 56, 56, 48)           0         ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)           (None, 56, 56, 48)           0         ['block2c_drop[0][0]',
#                                                                      'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2  (None, 56, 56, 192)          82944     ['block2c_add[0][0]']
#  D)
#
#  block2d_expand_bn (BatchNo  (None, 56, 56, 192)          768       ['block2d_expand_conv[0][0]']
#  rmalization)
#
#  block2d_expand_activation   (None, 56, 56, 192)          0         ['block2d_expand_bn[0][0]']
#  (Activation)
#
#  block2d_project_conv (Conv  (None, 56, 56, 48)           9216      ['block2d_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2d_project_bn (BatchN  (None, 56, 56, 48)           192       ['block2d_project_conv[0][0]']
#  ormalization)
#
#  block2d_drop (Dropout)      (None, 56, 56, 48)           0         ['block2d_project_bn[0][0]']
#
#  block2d_add (Add)           (None, 56, 56, 48)           0         ['block2d_drop[0][0]',
#                                                                      'block2c_add[0][0]']
#
#  block3a_expand_conv (Conv2  (None, 28, 28, 192)          82944     ['block2d_add[0][0]']
#  D)
#
#  block3a_expand_bn (BatchNo  (None, 28, 28, 192)          768       ['block3a_expand_conv[0][0]']
#  rmalization)
#
#  block3a_expand_activation   (None, 28, 28, 192)          0         ['block3a_expand_bn[0][0]']
#  (Activation)
#
#  block3a_project_conv (Conv  (None, 28, 28, 64)           12288     ['block3a_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3a_project_bn (BatchN  (None, 28, 28, 64)           256       ['block3a_project_conv[0][0]']
#  ormalization)
#
#  block3b_expand_conv (Conv2  (None, 28, 28, 256)          147456    ['block3a_project_bn[0][0]']
#  D)
#
#  block3b_expand_bn (BatchNo  (None, 28, 28, 256)          1024      ['block3b_expand_conv[0][0]']
#  rmalization)
#
#  block3b_expand_activation   (None, 28, 28, 256)          0         ['block3b_expand_bn[0][0]']
#  (Activation)
#
#  block3b_project_conv (Conv  (None, 28, 28, 64)           16384     ['block3b_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3b_project_bn (BatchN  (None, 28, 28, 64)           256       ['block3b_project_conv[0][0]']
#  ormalization)
#
#  block3b_drop (Dropout)      (None, 28, 28, 64)           0         ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)           (None, 28, 28, 64)           0         ['block3b_drop[0][0]',
#                                                                      'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2  (None, 28, 28, 256)          147456    ['block3b_add[0][0]']
#  D)
#
#  block3c_expand_bn (BatchNo  (None, 28, 28, 256)          1024      ['block3c_expand_conv[0][0]']
#  rmalization)
#
#  block3c_expand_activation   (None, 28, 28, 256)          0         ['block3c_expand_bn[0][0]']
#  (Activation)
#
#  block3c_project_conv (Conv  (None, 28, 28, 64)           16384     ['block3c_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3c_project_bn (BatchN  (None, 28, 28, 64)           256       ['block3c_project_conv[0][0]']
#  ormalization)
#
#  block3c_drop (Dropout)      (None, 28, 28, 64)           0         ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)           (None, 28, 28, 64)           0         ['block3c_drop[0][0]',
#                                                                      'block3b_add[0][0]']
#
#  block3d_expand_conv (Conv2  (None, 28, 28, 256)          147456    ['block3c_add[0][0]']
#  D)
#
#  block3d_expand_bn (BatchNo  (None, 28, 28, 256)          1024      ['block3d_expand_conv[0][0]']
#  rmalization)
#
#  block3d_expand_activation   (None, 28, 28, 256)          0         ['block3d_expand_bn[0][0]']
#  (Activation)
#
#  block3d_project_conv (Conv  (None, 28, 28, 64)           16384     ['block3d_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3d_project_bn (BatchN  (None, 28, 28, 64)           256       ['block3d_project_conv[0][0]']
#  ormalization)
#
#  block3d_drop (Dropout)      (None, 28, 28, 64)           0         ['block3d_project_bn[0][0]']
#
#  block3d_add (Add)           (None, 28, 28, 64)           0         ['block3d_drop[0][0]',
#                                                                      'block3c_add[0][0]']
#
#  block4a_expand_conv (Conv2  (None, 28, 28, 256)          16384     ['block3d_add[0][0]']
#  D)
#
#  block4a_expand_bn (BatchNo  (None, 28, 28, 256)          1024      ['block4a_expand_conv[0][0]']
#  rmalization)
#
#  block4a_expand_activation   (None, 28, 28, 256)          0         ['block4a_expand_bn[0][0]']
#  (Activation)
#
#  block4a_dwconv2 (Depthwise  (None, 14, 14, 256)          2304      ['block4a_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4a_bn (BatchNormaliza  (None, 14, 14, 256)          1024      ['block4a_dwconv2[0][0]']
#  tion)
#
#  block4a_activation (Activa  (None, 14, 14, 256)          0         ['block4a_bn[0][0]']
#  tion)
#
#  block4a_se_squeeze (Global  (None, 256)                  0         ['block4a_activation[0][0]']
#  AveragePooling2D)
#
#  block4a_se_reshape (Reshap  (None, 1, 1, 256)            0         ['block4a_se_squeeze[0][0]']
#  e)
#
#  block4a_se_reduce (Conv2D)  (None, 1, 1, 16)             4112      ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)  (None, 1, 1, 256)            4352      ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multipl  (None, 14, 14, 256)          0         ['block4a_activation[0][0]',
#  y)                                                                  'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv  (None, 14, 14, 128)          32768     ['block4a_se_excite[0][0]']
#  2D)
#
#  block4a_project_bn (BatchN  (None, 14, 14, 128)          512       ['block4a_project_conv[0][0]']
#  ormalization)
#
#  block4b_expand_conv (Conv2  (None, 14, 14, 512)          65536     ['block4a_project_bn[0][0]']
#  D)
#
#  block4b_expand_bn (BatchNo  (None, 14, 14, 512)          2048      ['block4b_expand_conv[0][0]']
#  rmalization)
#
#  block4b_expand_activation   (None, 14, 14, 512)          0         ['block4b_expand_bn[0][0]']
#  (Activation)
#
#  block4b_dwconv2 (Depthwise  (None, 14, 14, 512)          4608      ['block4b_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4b_bn (BatchNormaliza  (None, 14, 14, 512)          2048      ['block4b_dwconv2[0][0]']
#  tion)
#
#  block4b_activation (Activa  (None, 14, 14, 512)          0         ['block4b_bn[0][0]']
#  tion)
#
#  block4b_se_squeeze (Global  (None, 512)                  0         ['block4b_activation[0][0]']
#  AveragePooling2D)
#
#  block4b_se_reshape (Reshap  (None, 1, 1, 512)            0         ['block4b_se_squeeze[0][0]']
#  e)
#
#  block4b_se_reduce (Conv2D)  (None, 1, 1, 32)             16416     ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)  (None, 1, 1, 512)            16896     ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multipl  (None, 14, 14, 512)          0         ['block4b_activation[0][0]',
#  y)                                                                  'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv  (None, 14, 14, 128)          65536     ['block4b_se_excite[0][0]']
#  2D)
#
#  block4b_project_bn (BatchN  (None, 14, 14, 128)          512       ['block4b_project_conv[0][0]']
#  ormalization)
#
#  block4b_drop (Dropout)      (None, 14, 14, 128)          0         ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)           (None, 14, 14, 128)          0         ['block4b_drop[0][0]',
#                                                                      'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2  (None, 14, 14, 512)          65536     ['block4b_add[0][0]']
#  D)
#
#  block4c_expand_bn (BatchNo  (None, 14, 14, 512)          2048      ['block4c_expand_conv[0][0]']
#  rmalization)
#
#  block4c_expand_activation   (None, 14, 14, 512)          0         ['block4c_expand_bn[0][0]']
#  (Activation)
#
#  block4c_dwconv2 (Depthwise  (None, 14, 14, 512)          4608      ['block4c_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4c_bn (BatchNormaliza  (None, 14, 14, 512)          2048      ['block4c_dwconv2[0][0]']
#  tion)
#
#  block4c_activation (Activa  (None, 14, 14, 512)          0         ['block4c_bn[0][0]']
#  tion)
#
#  block4c_se_squeeze (Global  (None, 512)                  0         ['block4c_activation[0][0]']
#  AveragePooling2D)
#
#  block4c_se_reshape (Reshap  (None, 1, 1, 512)            0         ['block4c_se_squeeze[0][0]']
#  e)
#
#  block4c_se_reduce (Conv2D)  (None, 1, 1, 32)             16416     ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)  (None, 1, 1, 512)            16896     ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multipl  (None, 14, 14, 512)          0         ['block4c_activation[0][0]',
#  y)                                                                  'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv  (None, 14, 14, 128)          65536     ['block4c_se_excite[0][0]']
#  2D)
#
#  block4c_project_bn (BatchN  (None, 14, 14, 128)          512       ['block4c_project_conv[0][0]']
#  ormalization)
#
#  block4c_drop (Dropout)      (None, 14, 14, 128)          0         ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)           (None, 14, 14, 128)          0         ['block4c_drop[0][0]',
#                                                                      'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2  (None, 14, 14, 512)          65536     ['block4c_add[0][0]']
#  D)
#
#  block4d_expand_bn (BatchNo  (None, 14, 14, 512)          2048      ['block4d_expand_conv[0][0]']
#  rmalization)
#
#  block4d_expand_activation   (None, 14, 14, 512)          0         ['block4d_expand_bn[0][0]']
#  (Activation)
#
#  block4d_dwconv2 (Depthwise  (None, 14, 14, 512)          4608      ['block4d_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4d_bn (BatchNormaliza  (None, 14, 14, 512)          2048      ['block4d_dwconv2[0][0]']
#  tion)
#
#  block4d_activation (Activa  (None, 14, 14, 512)          0         ['block4d_bn[0][0]']
#  tion)
#
#  block4d_se_squeeze (Global  (None, 512)                  0         ['block4d_activation[0][0]']
#  AveragePooling2D)
#
#  block4d_se_reshape (Reshap  (None, 1, 1, 512)            0         ['block4d_se_squeeze[0][0]']
#  e)
#
#  block4d_se_reduce (Conv2D)  (None, 1, 1, 32)             16416     ['block4d_se_reshape[0][0]']
#
#  block4d_se_expand (Conv2D)  (None, 1, 1, 512)            16896     ['block4d_se_reduce[0][0]']
#
#  block4d_se_excite (Multipl  (None, 14, 14, 512)          0         ['block4d_activation[0][0]',
#  y)                                                                  'block4d_se_expand[0][0]']
#
#  block4d_project_conv (Conv  (None, 14, 14, 128)          65536     ['block4d_se_excite[0][0]']
#  2D)
#
#  block4d_project_bn (BatchN  (None, 14, 14, 128)          512       ['block4d_project_conv[0][0]']
#  ormalization)
#
#  block4d_drop (Dropout)      (None, 14, 14, 128)          0         ['block4d_project_bn[0][0]']
#
#  block4d_add (Add)           (None, 14, 14, 128)          0         ['block4d_drop[0][0]',
#                                                                      'block4c_add[0][0]']
#
#  block4e_expand_conv (Conv2  (None, 14, 14, 512)          65536     ['block4d_add[0][0]']
#  D)
#
#  block4e_expand_bn (BatchNo  (None, 14, 14, 512)          2048      ['block4e_expand_conv[0][0]']
#  rmalization)
#
#  block4e_expand_activation   (None, 14, 14, 512)          0         ['block4e_expand_bn[0][0]']
#  (Activation)
#
#  block4e_dwconv2 (Depthwise  (None, 14, 14, 512)          4608      ['block4e_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4e_bn (BatchNormaliza  (None, 14, 14, 512)          2048      ['block4e_dwconv2[0][0]']
#  tion)
#
#  block4e_activation (Activa  (None, 14, 14, 512)          0         ['block4e_bn[0][0]']
#  tion)
#
#  block4e_se_squeeze (Global  (None, 512)                  0         ['block4e_activation[0][0]']
#  AveragePooling2D)
#
#  block4e_se_reshape (Reshap  (None, 1, 1, 512)            0         ['block4e_se_squeeze[0][0]']
#  e)
#
#  block4e_se_reduce (Conv2D)  (None, 1, 1, 32)             16416     ['block4e_se_reshape[0][0]']
#
#  block4e_se_expand (Conv2D)  (None, 1, 1, 512)            16896     ['block4e_se_reduce[0][0]']
#
#  block4e_se_excite (Multipl  (None, 14, 14, 512)          0         ['block4e_activation[0][0]',
#  y)                                                                  'block4e_se_expand[0][0]']
#
#  block4e_project_conv (Conv  (None, 14, 14, 128)          65536     ['block4e_se_excite[0][0]']
#  2D)
#
#  block4e_project_bn (BatchN  (None, 14, 14, 128)          512       ['block4e_project_conv[0][0]']
#  ormalization)
#
#  block4e_drop (Dropout)      (None, 14, 14, 128)          0         ['block4e_project_bn[0][0]']
#
#  block4e_add (Add)           (None, 14, 14, 128)          0         ['block4e_drop[0][0]',
#                                                                      'block4d_add[0][0]']
#
#  block4f_expand_conv (Conv2  (None, 14, 14, 512)          65536     ['block4e_add[0][0]']
#  D)
#
#  block4f_expand_bn (BatchNo  (None, 14, 14, 512)          2048      ['block4f_expand_conv[0][0]']
#  rmalization)
#
#  block4f_expand_activation   (None, 14, 14, 512)          0         ['block4f_expand_bn[0][0]']
#  (Activation)
#
#  block4f_dwconv2 (Depthwise  (None, 14, 14, 512)          4608      ['block4f_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4f_bn (BatchNormaliza  (None, 14, 14, 512)          2048      ['block4f_dwconv2[0][0]']
#  tion)
#
#  block4f_activation (Activa  (None, 14, 14, 512)          0         ['block4f_bn[0][0]']
#  tion)
#
#  block4f_se_squeeze (Global  (None, 512)                  0         ['block4f_activation[0][0]']
#  AveragePooling2D)
#
#  block4f_se_reshape (Reshap  (None, 1, 1, 512)            0         ['block4f_se_squeeze[0][0]']
#  e)
#
#  block4f_se_reduce (Conv2D)  (None, 1, 1, 32)             16416     ['block4f_se_reshape[0][0]']
#
#  block4f_se_expand (Conv2D)  (None, 1, 1, 512)            16896     ['block4f_se_reduce[0][0]']
#
#  block4f_se_excite (Multipl  (None, 14, 14, 512)          0         ['block4f_activation[0][0]',
#  y)                                                                  'block4f_se_expand[0][0]']
#
#  block4f_project_conv (Conv  (None, 14, 14, 128)          65536     ['block4f_se_excite[0][0]']
#  2D)
#
#  block4f_project_bn (BatchN  (None, 14, 14, 128)          512       ['block4f_project_conv[0][0]']
#  ormalization)
#
#  block4f_drop (Dropout)      (None, 14, 14, 128)          0         ['block4f_project_bn[0][0]']
#
#  block4f_add (Add)           (None, 14, 14, 128)          0         ['block4f_drop[0][0]',
#                                                                      'block4e_add[0][0]']
#
#  block5a_expand_conv (Conv2  (None, 14, 14, 768)          98304     ['block4f_add[0][0]']
#  D)
#
#  block5a_expand_bn (BatchNo  (None, 14, 14, 768)          3072      ['block5a_expand_conv[0][0]']
#  rmalization)
#
#  block5a_expand_activation   (None, 14, 14, 768)          0         ['block5a_expand_bn[0][0]']
#  (Activation)
#
#  block5a_dwconv2 (Depthwise  (None, 14, 14, 768)          6912      ['block5a_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block5a_bn (BatchNormaliza  (None, 14, 14, 768)          3072      ['block5a_dwconv2[0][0]']
#  tion)
#
#  block5a_activation (Activa  (None, 14, 14, 768)          0         ['block5a_bn[0][0]']
#  tion)
#
#  block5a_se_squeeze (Global  (None, 768)                  0         ['block5a_activation[0][0]']
#  AveragePooling2D)
#
#  block5a_se_reshape (Reshap  (None, 1, 1, 768)            0         ['block5a_se_squeeze[0][0]']
#  e)
#
#  block5a_se_reduce (Conv2D)  (None, 1, 1, 32)             24608     ['block5a_se_reshape[0][0]']
#
#  block5a_se_expand (Conv2D)  (None, 1, 1, 768)            25344     ['block5a_se_reduce[0][0]']
#
#  block5a_se_excite (Multipl  (None, 14, 14, 768)          0         ['block5a_activation[0][0]',
#  y)                                                                  'block5a_se_expand[0][0]']
#
#  block5a_project_conv (Conv  (None, 14, 14, 160)          122880    ['block5a_se_excite[0][0]']
#  2D)
#
#  block5a_project_bn (BatchN  (None, 14, 14, 160)          640       ['block5a_project_conv[0][0]']
#  ormalization)
#
#  block5b_expand_conv (Conv2  (None, 14, 14, 960)          153600    ['block5a_project_bn[0][0]']
#  D)
#
#  block5b_expand_bn (BatchNo  (None, 14, 14, 960)          3840      ['block5b_expand_conv[0][0]']
#  rmalization)
#
#  block5b_expand_activation   (None, 14, 14, 960)          0         ['block5b_expand_bn[0][0]']
# ...
#  block6l_se_expand (Conv2D)  (None, 1, 1, 1536)           99840     ['block6l_se_reduce[0][0]']
#
#  block6l_se_excite (Multipl  (None, 7, 7, 1536)           0         ['block6l_activation[0][0]',
#  y)                                                                  'block6l_se_expand[0][0]']
#
#  block6l_project_conv (Conv  (None, 7, 7, 256)            393216    ['block6l_se_excite[0][0]']
#  2D)
#
#  block6l_project_bn (BatchN  (None, 7, 7, 256)            1024      ['block6l_project_conv[0][0]']
#  ormalization)
#
#  block6l_drop (Dropout)      (None, 7, 7, 256)            0         ['block6l_project_bn[0][0]']
#
#  block6l_add (Add)           (None, 7, 7, 256)            0         ['block6l_drop[0][0]',
#                                                                      'block6k_add[0][0]']
#
#  block6m_expand_conv (Conv2  (None, 7, 7, 1536)           393216    ['block6l_add[0][0]']
#  D)
#
#  block6m_expand_bn (BatchNo  (None, 7, 7, 1536)           6144      ['block6m_expand_conv[0][0]']
#  rmalization)
#
#  block6m_expand_activation   (None, 7, 7, 1536)           0         ['block6m_expand_bn[0][0]']
#  (Activation)
#
#  block6m_dwconv2 (Depthwise  (None, 7, 7, 1536)           13824     ['block6m_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block6m_bn (BatchNormaliza  (None, 7, 7, 1536)           6144      ['block6m_dwconv2[0][0]']
#  tion)
#
#  block6m_activation (Activa  (None, 7, 7, 1536)           0         ['block6m_bn[0][0]']
#  tion)
#
#  block6m_se_squeeze (Global  (None, 1536)                 0         ['block6m_activation[0][0]']
#  AveragePooling2D)
#
#  block6m_se_reshape (Reshap  (None, 1, 1, 1536)           0         ['block6m_se_squeeze[0][0]']
#  e)
#
#  block6m_se_reduce (Conv2D)  (None, 1, 1, 64)             98368     ['block6m_se_reshape[0][0]']
#
#  block6m_se_expand (Conv2D)  (None, 1, 1, 1536)           99840     ['block6m_se_reduce[0][0]']
#
#  block6m_se_excite (Multipl  (None, 7, 7, 1536)           0         ['block6m_activation[0][0]',
#  y)                                                                  'block6m_se_expand[0][0]']
#
#  block6m_project_conv (Conv  (None, 7, 7, 256)            393216    ['block6m_se_excite[0][0]']
#  2D)
#
#  block6m_project_bn (BatchN  (None, 7, 7, 256)            1024      ['block6m_project_conv[0][0]']
#  ormalization)
#
#  block6m_drop (Dropout)      (None, 7, 7, 256)            0         ['block6m_project_bn[0][0]']
#
#  block6m_add (Add)           (None, 7, 7, 256)            0         ['block6m_drop[0][0]',
#                                                                      'block6l_add[0][0]']
#
#  block6n_expand_conv (Conv2  (None, 7, 7, 1536)           393216    ['block6m_add[0][0]']
#  D)
#
#  block6n_expand_bn (BatchNo  (None, 7, 7, 1536)           6144      ['block6n_expand_conv[0][0]']
#  rmalization)
#
#  block6n_expand_activation   (None, 7, 7, 1536)           0         ['block6n_expand_bn[0][0]']
#  (Activation)
#
#  block6n_dwconv2 (Depthwise  (None, 7, 7, 1536)           13824     ['block6n_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block6n_bn (BatchNormaliza  (None, 7, 7, 1536)           6144      ['block6n_dwconv2[0][0]']
#  tion)
#
#  block6n_activation (Activa  (None, 7, 7, 1536)           0         ['block6n_bn[0][0]']
#  tion)
#
#  block6n_se_squeeze (Global  (None, 1536)                 0         ['block6n_activation[0][0]']
#  AveragePooling2D)
#
#  block6n_se_reshape (Reshap  (None, 1, 1, 1536)           0         ['block6n_se_squeeze[0][0]']
#  e)
#
#  block6n_se_reduce (Conv2D)  (None, 1, 1, 64)             98368     ['block6n_se_reshape[0][0]']
#
#  block6n_se_expand (Conv2D)  (None, 1, 1, 1536)           99840     ['block6n_se_reduce[0][0]']
#
#  block6n_se_excite (Multipl  (None, 7, 7, 1536)           0         ['block6n_activation[0][0]',
#  y)                                                                  'block6n_se_expand[0][0]']
#
#  block6n_project_conv (Conv  (None, 7, 7, 256)            393216    ['block6n_se_excite[0][0]']
#  2D)
#
#  block6n_project_bn (BatchN  (None, 7, 7, 256)            1024      ['block6n_project_conv[0][0]']
#  ormalization)
#
#  block6n_drop (Dropout)      (None, 7, 7, 256)            0         ['block6n_project_bn[0][0]']
#
#  block6n_add (Add)           (None, 7, 7, 256)            0         ['block6n_drop[0][0]',
#                                                                      'block6m_add[0][0]']
#
#  block6o_expand_conv (Conv2  (None, 7, 7, 1536)           393216    ['block6n_add[0][0]']
#  D)
#
#  block6o_expand_bn (BatchNo  (None, 7, 7, 1536)           6144      ['block6o_expand_conv[0][0]']
#  rmalization)
#
#  block6o_expand_activation   (None, 7, 7, 1536)           0         ['block6o_expand_bn[0][0]']
#  (Activation)
#
#  block6o_dwconv2 (Depthwise  (None, 7, 7, 1536)           13824     ['block6o_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block6o_bn (BatchNormaliza  (None, 7, 7, 1536)           6144      ['block6o_dwconv2[0][0]']
#  tion)
#
#  block6o_activation (Activa  (None, 7, 7, 1536)           0         ['block6o_bn[0][0]']
#  tion)
#
#  block6o_se_squeeze (Global  (None, 1536)                 0         ['block6o_activation[0][0]']
#  AveragePooling2D)
#
#  block6o_se_reshape (Reshap  (None, 1, 1, 1536)           0         ['block6o_se_squeeze[0][0]']
#  e)
#
#  block6o_se_reduce (Conv2D)  (None, 1, 1, 64)             98368     ['block6o_se_reshape[0][0]']
#
#  block6o_se_expand (Conv2D)  (None, 1, 1, 1536)           99840     ['block6o_se_reduce[0][0]']
#
#  block6o_se_excite (Multipl  (None, 7, 7, 1536)           0         ['block6o_activation[0][0]',
#  y)                                                                  'block6o_se_expand[0][0]']
#
#  block6o_project_conv (Conv  (None, 7, 7, 256)            393216    ['block6o_se_excite[0][0]']
#  2D)
#
#  block6o_project_bn (BatchN  (None, 7, 7, 256)            1024      ['block6o_project_conv[0][0]']
#  ormalization)
#
#  block6o_drop (Dropout)      (None, 7, 7, 256)            0         ['block6o_project_bn[0][0]']
#
#  block6o_add (Add)           (None, 7, 7, 256)            0         ['block6o_drop[0][0]',
#                                                                      'block6n_add[0][0]']
#
#  top_conv (Conv2D)           (None, 7, 7, 1280)           327680    ['block6o_add[0][0]']
#
#  top_bn (BatchNormalization  (None, 7, 7, 1280)           5120      ['top_conv[0][0]']
#  )
#
#  top_activation (Activation  (None, 7, 7, 1280)           0         ['top_bn[0][0]']
#  )
#
#  global_average_pooling2d (  (None, 1280)                 0         ['top_activation[0][0]']
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1280)                 0         ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dense (Dense)               (None, 10)                   12810     ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 20344170 (77.61 MB)
# Trainable params: 18368722 (70.07 MB)
# Non-trainable params: 1975448 (7.54 MB)
# __________________________________________________________________________________________________

# %% [markdown]
# # Training our model

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
callbacks = [
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, min_lr=0.00001),
    EarlyStopping(monitor='val_loss', mode='min', patience=4, restore_best_weights=True, verbose=1)
]

checkpoint_callback = ModelCheckpoint(
    'robin_efficientnetv2s.keras',
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    verbose=1
)

# %%
history = model.fit(
    train_generator,
    steps_per_epoch=len(train_generator),
    validation_data=val_generator,
    validation_steps=len(val_generator),
    epochs=100,
    callbacks=[callbacks, checkpoint_callback]
)
# Out:
# Epoch 1/100
# 328/328 [==============================] - ETA: 0s - loss: 0.8513 - accuracy: 0.7275
# Epoch 1: val_loss improved from inf to 0.28991, saving model to robin_efficientnetv2s.keras
# 328/328 [==============================] - 464s 1s/step - loss: 0.8513 - accuracy: 0.7275 - val_loss: 0.2899 - val_accuracy: 0.9097 - lr: 1.0000e-04
# Epoch 2/100
# 328/328 [==============================] - ETA: 0s - loss: 0.3157 - accuracy: 0.8991
# Epoch 2: val_loss improved from 0.28991 to 0.21142, saving model to robin_efficientnetv2s.keras
# 328/328 [==============================] - 395s 1s/step - loss: 0.3157 - accuracy: 0.8991 - val_loss: 0.2114 - val_accuracy: 0.9325 - lr: 1.0000e-04
# Epoch 3/100
# 328/328 [==============================] - ETA: 0s - loss: 0.2177 - accuracy: 0.9299
# Epoch 3: val_loss improved from 0.21142 to 0.18499, saving model to robin_efficientnetv2s.keras
# 328/328 [==============================] - 395s 1s/step - loss: 0.2177 - accuracy: 0.9299 - val_loss: 0.1850 - val_accuracy: 0.9420 - lr: 1.0000e-04
# Epoch 4/100
# 328/328 [==============================] - ETA: 0s - loss: 0.1563 - accuracy: 0.9487
# Epoch 4: val_loss did not improve from 0.18499
# 328/328 [==============================] - 391s 1s/step - loss: 0.1563 - accuracy: 0.9487 - val_loss: 0.1857 - val_accuracy: 0.9410 - lr: 1.0000e-04
# Epoch 5/100
# 328/328 [==============================] - ETA: 0s - loss: 0.1291 - accuracy: 0.9579
# Epoch 5: val_loss did not improve from 0.18499
# 328/328 [==============================] - 392s 1s/step - loss: 0.1291 - accuracy: 0.9579 - val_loss: 0.1901 - val_accuracy: 0.9457 - lr: 1.0000e-04
# Epoch 6/100
# 328/328 [==============================] - ETA: 0s - loss: 0.0828 - accuracy: 0.9744
# Epoch 6: val_loss improved from 0.18499 to 0.18203, saving model to robin_efficientnetv2s.keras
# 328/328 [==============================] - 397s 1s/step - loss: 0.0828 - accuracy: 0.9744 - val_loss: 0.1820 - val_accuracy: 0.9477 - lr: 5.0000e-05
# Epoch 7/100
# 328/328 [==============================] - ETA: 0s - loss: 0.0680 - accuracy: 0.9790
# Epoch 7: val_loss did not improve from 0.18203
# 328/328 [==============================] - 410s 1s/step - loss: 0.0680 - accuracy: 0.9790 - val_loss: 0.1871 - val_accuracy: 0.9505 - lr: 5.0000e-05
# Epoch 8/100
# 328/328 [==============================] - ETA: 0s - loss: 0.0604 - accuracy: 0.9808
# Epoch 8: val_loss did not improve from 0.18203
# 328/328 [==============================] - 390s 1s/step - loss: 0.0604 - accuracy: 0.9808 - val_loss: 0.1885 - val_accuracy: 0.9505 - lr: 5.0000e-05
# Epoch 9/100
# 328/328 [==============================] - ETA: 0s - loss: 0.0492 - accuracy: 0.9842
# Epoch 9: val_loss did not improve from 0.18203
# 328/328 [==============================] - 391s 1s/step - loss: 0.0492 - accuracy: 0.9842 - val_loss: 0.1955 - val_accuracy: 0.9478 - lr: 2.5000e-05
# Epoch 10/100
# 328/328 [==============================] - ETA: 0s - loss: 0.0457 - accuracy: 0.9858Restoring model weights from the end of the best epoch: 6.
#
# Epoch 10: val_loss did not improve from 0.18203
# 328/328 [==============================] - 392s 1s/step - loss: 0.0457 - accuracy: 0.9858 - val_loss: 0.1913 - val_accuracy: 0.9518 - lr: 2.5000e-05
# Epoch 10: early stopping

# %% [markdown]
# # Learning curves and model performance

# %%
def plot_learning_curves(history, start_epoch=5):
    """
    Plot training and validation loss and accuracy curves.

    Parameters:
    - history: Training history (output from the model's fit method).
    - start_epoch: Epoch from which to start plotting. Default is 5 (i.e., plot from epoch 6 onwards).
    """

    df = pd.DataFrame(history.history)
    df = df.iloc[start_epoch-1:]
    sns.set(rc={'axes.facecolor': '#f0f0fc'}, style='darkgrid')

    plt.figure(figsize=(15,6))
    plt.subplot(1, 2, 1)
    sns.lineplot(x=df.index, y=df['loss'], color='royalblue', label='Train Loss')
    sns.lineplot(x=df.index, y=df['val_loss'], color='orangered', linestyle='--', label='Validation Loss')
    plt.title('Loss Evolution')
    plt.subplot(1, 2, 2)
    sns.lineplot(x=df.index, y=df['accuracy'], color='royalblue', label='Train Accuracy')
    sns.lineplot(x=df.index, y=df['val_accuracy'], color='orangered', linestyle='--', label='Validation Accuracy')
    plt.title('Accuracy Evolution')

    plt.show()

# %%
plot_learning_curves(history, start_epoch=1)

# %%
def evaluate_model_performance(model, val_generator, class_labels):
    """
    Evaluate the model's performance on the validation set and print the classification report.

    Parameters:
    - model: The trained model.
    - val_generator: Validation data generator.
    - class_labels: List of class names.

    Returns:
    - report: Classification report as a string.
    """

    true_labels = val_generator.classes
    class_labels = list(val_generator.class_indices.keys())
    predictions = model.predict(val_generator, steps=len(val_generator))
    predicted_labels = np.argmax(predictions, axis=1)
    true_labels = val_generator.classes
    report = classification_report(true_labels, predicted_labels, target_names=class_labels)
    print(report)
    print('\n')

    colors = ["white", "royalblue"]
    cmap_cm = LinearSegmentedColormap.from_list("cmap_cm", colors)
    cm = confusion_matrix(true_labels, predicted_labels)

    plt.figure(figsize=(8,6))
    sns.heatmap(cm, annot=True, cmap=cmap_cm, fmt='d', xticklabels=class_labels, yticklabels=class_labels)
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.title('Confusion Matrix')
    plt.show()

# %%
class_labels = list(test_generator.class_indices.keys())
evaluate_model_performance(model, test_generator, class_labels)
# Out:
# 48/48 [==============================] - 15s 250ms/step
#               precision    recall  f1-score   support
#
# buah_sayuran       0.92      0.93      0.93       301
#         daun       0.98      0.97      0.97       301
#   elektronik       0.99      0.97      0.98       301
#         kaca       0.94      0.96      0.95       301
#       kertas       0.96      0.95      0.95       301
#        logam       0.93      0.96      0.95       301
#      makanan       0.93      0.93      0.93       301
#        medis       0.95      0.97      0.96       301
#      plastik       0.93      0.90      0.92       301
#      tekstil       0.99      0.99      0.99       301
#
#     accuracy                           0.95      3010
#    macro avg       0.95      0.95      0.95      3010
# weighted avg       0.95      0.95      0.95      3010

# %% [markdown]
# # Testing the model

# %%
import random

def plot_random_predictions(model, test_dir, class_labels, num_images=36, seed=None):
    """
    Plot a grid of random predictions for test images from different class folders.

    Parameters:
    - model: The trained model.
    - test_dir: Path to the test dataset directory.
    - class_labels: List of class labels.
    - num_images: Number of random images to display.
    - seed: Seed for random number generation (optional).
    """

    random.seed(seed)

    class_folders = [os.path.join(test_dir, class_label) for class_label in class_labels]

    fig, axs = plt.subplots(6, 6, figsize=(15, 15))
    axs = axs.ravel()

    for i in range(num_images):
        random_class = random.choice(class_folders)
        random_image_path = random.choice([os.path.join(random_class, img) for img in os.listdir(random_class) if img.endswith(('jpg', 'jpeg', 'png'))])

        true_label = os.path.basename(random_class)  # True label is the folder name

        with Image.open(random_image_path) as img:
            axs[i].imshow(img)
            axs[i].axis('off')

            img_resized = img.resize((224, 224))
            img_array = np.expand_dims(np.array(img_resized), axis=0)
            img_array = preprocess_input(img_array)

            prediction = model.predict(img_array)
            predicted_class = class_labels[np.argmax(prediction)]
            confidence_score = np.max(prediction)  # Confidence score is the probability of the predicted class

            axs[i].set_title(f"True: {true_label}\nPredicted: {predicted_class}\nConfidence: {confidence_score:.2f}")

    plt.tight_layout()
    plt.show()

# %%
plot_random_predictions(model, test_dir, class_labels)
# Out:
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 32ms/step

# %% [markdown]
# # Save the model

# %%
import shutil

saved_path = "/working/robin_efficientnetv2s"

# %%
model.save(saved_path, save_format="tf")
print(f"Model saved to {saved_path}")

# %%
output_zip_path = "/working/robin_efficientnetv2s.zip"

shutil.make_archive(output_zip_path.replace('.zip', ''), 'zip', saved_path)
print(f"Model zipped and saved at {output_zip_path}")
